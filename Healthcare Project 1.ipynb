# %% [markdown]
# # About data :- Health Care

# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
#  # Importing Dataset

# %%
data =  pd.read_csv("E:\pandas project1\data\healthcare_dataset.csv")

data
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# # Total Column and Row in dataset

# %%
print ("Total Rows and Column of the dataset")
print()
print()
print("Number of Column :", data.shape[1])
print()
print("Number of Rows :", data.shape[0])
# Out:
# Total Rows and Column of the dataset
#
#
# Number of Column : 14
#
# Number of Rows : 10000

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# # Remove unwanted columns

# %%
data.drop(columns=['Doctor','Room Number','Hospital'],inplace=True)

data.head(3)
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# 0  Tiffany Ramirez   81  Female         O-          Diabetes
# 1      Ruben Burns   35    Male         O+            Asthma
# 2        Chad Byrd   61    Male         B-           Obesity
#
#   Date of Admission  Billing Amount Admission Type Discharge Date Medication  \
# 0        17-11-2022     37490.98336       Elective     01-12-2022    Aspirin
# 1        01-06-2023     47304.06485      Emergency     15-06-2023    Lipitor
# 2        09-01-2019     36874.89700      Emergency     08-02-2019    Lipitor
#
#    Test Results
# 0  Inconclusive
# 1        Normal
# 2        Normal

# %% [markdown]
# # Info of the data

# %%
print ("To find the information about data like null value, int,str,size of data and so on")
data.info()
# Out:
# To find the information about data like null value, int,str,size of data and so on
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               10000 non-null  object
#  1   Age                10000 non-null  int64
#  2   Gender             10000 non-null  object
#  3   Blood Type         10000 non-null  object
#  4   Medical Condition  10000 non-null  object
#  5   Date of Admission  10000 non-null  object
#  6   Billing Amount     10000 non-null  float64
#  7   Admission Type     10000 non-null  object
#  8   Discharge Date     10000 non-null  object
#  9   Medication         10000 non-null  object
#  10  Test Results       10000 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 859.5+ KB

# %% [markdown]
# # Aim

# %% [markdown]
# # "To find the data or numbers of the age groups affected by various diseases in individuals."

# %%
# Working on this columns

selected_columns = data[['Age', 'Gender', 'Medical Condition']]

selected_columns
# Out:
#       Age  Gender Medical Condition
# 0      81  Female          Diabetes
# 1      35    Male            Asthma
# 2      61    Male           Obesity
# 3      49    Male            Asthma
# 4      51    Male         Arthritis
# ...   ...     ...               ...
# 9995   83    Male           Obesity
# 9996   47  Female         Arthritis
# 9997   54    Male         Arthritis
# 9998   84    Male         Arthritis
# 9999   20    Male         Arthritis
#
# [10000 rows x 3 columns]

# %%
# Finding the Maximum And Minimun Age of the dataset

min_age = data['Age'].min()
max_age = data['Age'].max()

print(f"The minimum age in the dataset is: {min_age} years")
print(f"The maximum age in the dataset is: {max_age} years")
# Out:
# The minimum age in the dataset is: 18 years
# The maximum age in the dataset is: 85 years

# %%
#Creating the function to finding Diseases for Random Age Group

def diseases_by_age_gender(data):
    age_min = int(input("Enter the minimum age: "))
    age_max = int(input("Enter the maximum age: "))
   
    filtered_data = data[(data['Age'] >= age_min) & (data['Age'] <= age_max)]

    if filtered_data.empty:
        print("No data available for the specified age range.")
        return
    
    grouped_data = filtered_data.groupby(['Gender', 'Medical Condition']).size().unstack(fill_value=0)

    print(f"Distribution of Diseases for Age Group {age_min} to {age_max}:")
    print(grouped_data)
    

    sns.set(style="whitegrid")
    plt.figure(figsize=(12, 6))
# Plotting the graph
    sns.countplot(data=data, x='Medical Condition', hue='Gender', palette='Set1')
    plt.title("Distribution of Medical Conditions by Gender")
    plt.xlabel("Medical Condition")
    plt.ylabel("Number of Patients")
    plt.xticks(rotation=90)
    plt.legend(title='Gender')
    plt.show()
    
    
    # Plotting using seaborn Bar Plot
    plt.figure(figsize=(10, 6))
    sns.barplot(data=grouped_data, palette="YlGnBu")
    plt.title(f"Distribution of Diseases for Age Group {age_min} to {age_max}")
    plt.xlabel("Medical Condition")
    plt.ylabel("Count")
    plt.show()
    

diseases_by_age_gender(data)
# Out:
# Enter the minimum age: 18
# Enter the maximum age: 85
# Distribution of Diseases for Age Group 18 to 85:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Gender
# Female                   815     874     887       825           836      838
# Male                     835     834     816       798           852      790

# %%
# making Age group 10-10 

data['Date of Admission'] = pd.to_datetime(data['Date of Admission'])

filtered_data = data[(data['Date of Admission'].dt.year >= 2018) & (data['Date of Admission'].dt.year <= 2023)]

age_bins = [18, 27, 37, 47, 57, 67, 77, 85]
age_labels = ['18-27', '28-37', '38-47', '48-57', '58-67', '68-77', '78-85']

filtered_data['Age Group'] = pd.cut(filtered_data['Age'], bins=age_bins, labels=age_labels, right=False)


grouped_data = filtered_data.groupby(['Age Group', 'Medical Condition']).size().unstack(fill_value=0)


print("Distribution of Diseases by Age Group from 2018 to 2023:")
print(grouped_data)


# Plot the distribution of diseases among different age groups
plt.figure(figsize=(12, 8))
grouped_data.plot(kind='bar', stacked=True)
plt.title("Distribution of Diseases by Age Group from 2018 to 2023")
plt.xlabel("Age Group")
plt.ylabel("Number of Cases")
plt.xticks(rotation=45, ha='right')
plt.legend(title='Medical Condition', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SHUBHAM\AppData\Local\Temp\ipykernel_26208\1366465692.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Date of Admission'] = pd.to_datetime(data['Date of Admission'])
# Distribution of Diseases by Age Group from 2018 to 2023:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Age Group
# 18-27                    211     225     226       221           247      204
# 28-37                    249     253     257       223           250      249
# 38-47                    234     249     239       225           257      225
# 48-57                    248     256     243       239           224      242
# 58-67                    248     255     256       250           260      254
# 68-77                    258     249     245       249           240      239
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Aim2

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Billing Amount', 'Admission Type',
#        'Discharge Date', 'Medication', 'Test Results'],
#       dtype='object')

# %%
selected_columns = data[['Age', 'Gender', 'Blood Type', 'Medical Condition']]

selected_columns
# Out:
#       Age  Gender Blood Type Medical Condition
# 0      81  Female         O-          Diabetes
# 1      35    Male         O+            Asthma
# 2      61    Male         B-           Obesity
# 3      49    Male         B-            Asthma
# 4      51    Male         O-         Arthritis
# ...   ...     ...        ...               ...
# 9995   83    Male         A+           Obesity
# 9996   47  Female        AB+         Arthritis
# 9997   54    Male         B-         Arthritis
# 9998   84    Male         A+         Arthritis
# 9999   20    Male         B-         Arthritis
#
# [10000 rows x 4 columns]

# %%
# making a function to give input to pirticular input and getting the output gender(male,female) and their diseases

def medical_condition_gender_by_blood_type(data):
    blood_type_input = input("Enter the blood type (O-, O+, B-, AB+, A+): ").upper()
    
  
    filtered_data = data[data['Blood Type'] == blood_type_input]

    if filtered_data.empty:
        print("No data available for the specified blood type.")
        return
    

    grouped_data = filtered_data.groupby(['Medical Condition', 'Gender']).size()

    print(f"Medical Condition and Gender Distribution for Blood Type {blood_type_input}:")
    print(grouped_data)

    
    
    
# Plotting the graph
    plt.figure(figsize=(12, 6))
    sns.countplot(data=filtered_data, x='Medical Condition', hue='Gender', palette='Set1')
    plt.title(f"Medical Condition Distribution by Gender for Blood Type {blood_type_input}")
    plt.xlabel("Medical Condition")
    plt.ylabel("Number of Patients")
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Gender')
    plt.show()

# %%
medical_condition_gender_by_blood_type(data)
# Out:
# Enter the blood type (O-, O+, B-, AB+, A+): O+
# Medical Condition and Gender Distribution for Blood Type O+:
# Medical Condition  Gender
# Arthritis          Female    111
#                    Male      114
# Asthma             Female    117
#                    Male      110
# Cancer             Female    131
#                    Male       93
# Diabetes           Female     80
#                    Male       94
# Hypertension       Female    104
#                    Male      105
# Obesity            Female     98
#                    Male       91
# dtype: int64

# %%
# the function on giving the input of two age and get the output on this age group whivh diseases are count the blood group

def medical_condition_blood_type_relationship(data):
    age1 = int(input("Enter the first age: "))
    age2 = int(input("Enter the second age: "))
    
    # Filter the data for patients within the specified age range
    filtered_data = data[(data['Age'] >= age1) & (data['Age'] <= age2)]
    
    if filtered_data.empty:
        print("No data available for the specified age range.")
        return
    
    # Group data by 'Medical Condition' and 'Blood Type', then calculate the count of patients
    grouped_data = filtered_data.groupby(['Medical Condition', 'Blood Type']).size().unstack(fill_value=0)

    print(f"Relationship between Medical Condition and Blood Type for patients aged {age1} to {age2}:")
    print(grouped_data)
    
    # Plotting the graph
    plt.figure(figsize=(12, 6))
    sns.heatmap(grouped_data, cmap='YlGnBu', annot=True, fmt='g', linewidths=0.5)
    plt.title(f"Relationship between Medical Condition and Blood Type for patients aged {age1} to {age2}")
    plt.xlabel("Blood Type")
    plt.ylabel("Medical Condition")
    plt.show()

# %%
medical_condition_blood_type_relationship(data)
# Out:
# Enter the first age: 18
# Enter the second age: 85
# Relationship between Medical Condition and Blood Type for patients aged 18 to 85:
# Blood Type          A+   A-  AB+  AB-   B+   B-   O+   O-
# Medical Condition
# Arthritis          202  202  219  204  196  186  225  216
# Asthma             220  208  199  210  217  218  227  209
# Cancer             219  218  208  195  214  221  224  204
# Diabetes           197  206  207  214  207  221  174  197
# Hypertension       213  212  211  225  211  196  209  211
# Obesity            190  192  214  227  199  210  189  207
